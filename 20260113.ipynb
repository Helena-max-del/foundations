# %% [markdown]
# <a href="https://colab.research.google.com/github/Helena-max-del/foundations/blob/main/20260113.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install duckdb leafmap
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.9/632.9 kB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 78.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 100.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 84.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
# ...

# %%
import duckdb
import leafmap
import pandas as pd

# %%
con = duckdb.connect()

# %%
con.install_extension("httpfs")
con.load_extension("httpfs")

# %%
url = "https://storage.googleapis.com/qm2/CASA0025/cities.zip"
leafmap.download_file(url, unzip=True, overwrite=True)
# Out:
# Downloading...
# From: https://storage.googleapis.com/qm2/CASA0025/cities.zip
# To: /content/cities.zip
# 100%|██████████| 214k/214k [00:00<00:00, 44.8MB/s]
# Extracting files...
# '/content/cities.zip'

# %%
# read from a file using fully auto-detected settings
con.read_csv('cities.csv')
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...

# %%
# specify options on how the CSV is formatted internally
con.read_csv('cities.csv', header=True, sep=',')
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...

# %%
# use the (experimental) parallel CSV reader
con.read_csv('cities.csv', parallel=True)
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...

# %%
# directly read a CSV file from within SQL
con.sql("SELECT * FROM 'cities.csv'")
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...

# %%
# call read_csv from within SQL
con.sql("SELECT * FROM read_csv_auto('cities.csv')")
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...

# %%
# read from a single JSON file
con.read_json('cities.json')
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...

# %%
# directly read a JSON file from within SQL
con.sql("SELECT * FROM 'cities.json'")
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...

# %%
# call read_json from within SQL
con.sql("SELECT * FROM read_json_auto('cities.json')")
# Out:
# ┌───────┬──────────────────┬─────────┬───────────┬───────────┬────────────┐
# │  id   │       name       │ country │ latitude  │ longitude │ population │
# │ int64 │     varchar      │ varchar │  double   │  double   │   int64    │
# ├───────┼──────────────────┼─────────┼───────────┼───────────┼────────────┤
# │     1 │ Bombo            │ UGA     │    0.5833 │   32.5333 │      75000 │
# │     2 │ Fort Portal      │ UGA     │     0.671 │    30.275 │      42670 │
# │     3 │ Potenza          │ ITA     │    40.642 │    15.799 │      69060 │
# │     4 │ Campobasso       │ ITA     │    41.563 │    14.656 │      50762 │
# │     5 │ Aosta            │ ITA     │    45.737 │     7.315 │      34062 │
# │     6 │ Mariehamn        │ ALD     │    60.097 │    19.949 │      10682 │
# │     7 │ Ramallah         │ PSE     │  31.90294 │  35.20621 │      24599 │
# │     8 │ Vatican City     │ VAT     │  41.90001 │  12.44781 │        832 │
# ...
